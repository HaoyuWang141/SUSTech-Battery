# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
def read_data(eis_file):
    EIS_list = []

    # eis in EIS_list:
    """
    eis = {
        cycle: int,
        size: int,
        freq: [],
        Re: [],
        Im: [],
    }
    """
    
    with pd.ExcelFile(eis_file) as df_eis:
        for sheet_name in df_eis.sheet_names:
            df = pd.read_excel(df_eis, sheet_name)
            cycle = int(sheet_name.split('-')[1])
            freq = df['freq/Hz'].values
            Re = df['Re(Z)/Ohm'].values
            Im = df['-Im(Z)/Ohm'].values
            size = len(freq)
            eis = {
                'cycle': cycle,
                'size': size,
                'freq': freq,
                'Re': Re,
                'Im': Im,
            }
            EIS_list.append(eis)

    
    return EIS_list

# %%
EIS_list_2A_1 = read_data('./2.0A-1 EIS.xlsx')
EIS_list_2A_2 = read_data('./2.0A-2 EIS.xlsx')
EIS_list_3A_1 = read_data('./3.0A-1 EIS.xlsx')
EIS_list_3A_2 = read_data('./3.0A-2 EIS.xlsx')

# %%
print(len(EIS_list_2A_1))
print(len(EIS_list_2A_2))
print(len(EIS_list_3A_1))
print(len(EIS_list_3A_2))
# Out:
# 47
# 45
# 49
# 49

# %%
for eis in EIS_list_2A_2:
    print(eis['cycle'], eis['size'])
    print(max(eis['freq']), min(eis['freq']))
    cnt = 0
    for freq in eis['freq']:
        if freq >= 0.1 and freq <= 20:
            cnt += 1
    print(f"0.1-20 Hz: {cnt}")
# Out:
# 10 105
# 100003.71 0.010009173
# 0.1-20 Hz: 35
# 41 105
# 100003.71 0.010009173
# 0.1-20 Hz: 35
# 50 105
# 100003.71 0.010009173
# 0.1-20 Hz: 35
# 59 105
# 100003.71 0.010009173
# 0.1-20 Hz: 35
# 70 105
# 100003.71 0.010009173
# 0.1-20 Hz: 35
# 80 105
# 100003.71 0.010009173
# 0.1-20 Hz: 35
# 90 105
# 100003.71 0.010009173
# 0.1-20 Hz: 35
# 100 105
# 100003.71 0.010009173
# 0.1-20 Hz: 35
# 110 105
# 100003.71 0.010009173
# 0.1-20 Hz: 35
# 120 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 130 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 140 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 150 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 160 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 170 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 180 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 190 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 200 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 210 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 220 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 230 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 240 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 689 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 700 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 710 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 720 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 740 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 750 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 760 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 770 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 780 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 790 101
# 100003.71 0.019992474
# 0.1-20 Hz: 34
# 800 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 810 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 820 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 830 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 840 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 850 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 860 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 870 65
# 29997.4 0.010009173
# 0.1-20 Hz: 23
# 880 67
# 100003.71 0.019992474
# 0.1-20 Hz: 23
# 890 67
# 100003.71 0.019992474
# 0.1-20 Hz: 23
# 900 67
# 100003.71 0.019992474
# 0.1-20 Hz: 23
# 910 67
# 100003.71 0.019992474
# 0.1-20 Hz: 23
# 920 67
# 100003.71 0.019992474
# 0.1-20 Hz: 23

# %% [markdown]
# 选择绘图的 style

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# for style in plt.style.available:
#     print(style)

plt.style.use(style="seaborn-v0_8-talk")
sns.set_theme(style="darkgrid")

# %% [markdown]
# 选择配色方案（sns的color_palette）

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

PALETTE = "Blues"
sns.palplot(sns.color_palette(PALETTE))
matrix = np.linspace(1, 600, 5).reshape(5, 1).astype(int)
fig = plt.figure(figsize=(1, 5))
sns_plot = sns.heatmap(
    matrix,
    annot=True,
    cmap=PALETTE,
    cbar=True,
    fmt=".0f",
    xticklabels=False,
    yticklabels=False,
)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_eis_data(EIS_list):
    palette = sns.color_palette(PALETTE, n_colors=len(EIS_list))
    
    # 创建一个图和轴
    plt.figure(figsize=(10, 6))  # 稍微增加图的宽度以容纳图例
    
    # 遍历EIS数据列表
    for idx, eis in enumerate(EIS_list):
        # if eis['cycle'] < 250:
        #     continue
        # 绘制Nyquist图，实部Re作为X轴，虚部Im作为Y轴
        plt.scatter(eis['Re'], eis['Im'], color=palette[idx], label=f'Cycle {eis["cycle"]}', s=8)
        plt.plot(eis['Re'], eis['Im'], color=palette[idx])
        

    # 添加图例、标题和轴标签
    # plt.legend(title="EIS Cycle", loc='center left', bbox_to_anchor=(1, 0.5), fontsize=7, title_fontsize='large')
    plt.title("Nyquist Plot of EIS Data", fontsize=18)
    plt.xlabel("Real Part (Re)", fontsize=16)
    plt.ylabel("Imaginary Part (Im)", fontsize=16)
    
    plt.ylim(-0.01, 0.06)

    # 适当调整子图参数，使图例不会被切割
    plt.subplots_adjust(right=0.75)

    # 显示图形
    plt.show()

# %%
plot_eis_data(EIS_list_2A_1)

# %%
plot_eis_data(EIS_list_2A_2)

# %%
plot_eis_data(EIS_list_3A_1)

# %%
plot_eis_data(EIS_list_3A_2)
